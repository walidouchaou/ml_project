# %%
# !pip install -r C:/Users/ouchaou/Desktop/ML/requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: pandas in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (3.9.3)
# Requirement already satisfied: seaborn in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: xgboost in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: lightgbm in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 7)) (4.6.0)
# Requirement already satisfied: statsmodels in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 8)) (0.14.4)
# Requirement already satisfied: prophet in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (1.1.6)
# Requirement already satisfied: yfinance in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (0.2.54)
# Requirement already satisfied: python-dotenv in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: duckdb in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 12)) (1.1.3)
# Requirement already satisfied: optuna in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (4.2.1)
# Requirement already satisfied: joblib in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from -r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from statsmodels->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (1.2.5)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (0.69)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: importlib-resources in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (6.5.2)
# Requirement already satisfied: requests>=2.31 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: colorlog in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (2.0.39)
# Requirement already satisfied: PyYAML in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (6.0.2)
# Requirement already satisfied: Mako in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from alembic>=1.5.0->optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (1.3.9)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from alembic>=1.5.0->optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (2.6)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from cmdstanpy>=1.0.4->prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 10)) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy>=1.4.2->optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: colorama in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.36.1->prophet->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\ouchaou\appdata\local\programs\python\python313\lib\site-packages (from Mako->alembic>=1.5.0->optuna->-r C:/Users/ouchaou/Desktop/ML/requirements.txt (line 13)) (3.0.0)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\ouchaou\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\ouchaou\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\ouchaou\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import duckdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna

# ----------------------------------------------------------------
# Étape 1 : Chargement des données et nettoyage
# ----------------------------------------------------------------
con = duckdb.connect("C:/Users/ouchaou/Desktop/ML/src/data/trades.duckdb")
query = "select * from trades_with_indicators_view where datetime > '2024-03-01 00:10:00' ;"
df = con.execute(query).fetchdf()
con.close()

# Suppression des lignes avec valeurs manquantes
df = df.dropna()
print(f"Nombre de valeurs NaN dans le DataFrame: {df.isna().sum().sum()}")

# ----------------------------------------------------------------
# Étape 2 : Création de la cible et sélection des features
# ----------------------------------------------------------------
df['target'] = df['close_price'].shift(-1)
df = df.dropna()  # Supprimer les lignes NaN après le shift

features = [
    'BB_upper', 'min_price', 'max_price', 'EMA_50', 'open_price'
]



X = df[features]
y = df['target']

# ----------------------------------------------------------------
# Étape 3 : Division train/test et normalisation
# ----------------------------------------------------------------
# Division des données en ensembles d'entraînement (80%) et de test (20%)
# test_size=0.2 signifie que 20% des données sont réservées pour le test
# shuffle=False conserve l'ordre chronologique des données, important pour les séries temporelles
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ----------------------------------------------------------------
# Étape 4 : Recherche d'hyperparamètres avec validation croisée temporelle
#-----------------------------------------------------------------
# def objective(trial):
#     # Nous fixons un nombre d'estimateurs élevé pour laisser la place à l'early stopping
#     n_estimators = trial.suggest_int("n_estimators", 100, 300)

#     # Réduction de l'espace de recherche pour concentrer la recherche sur des plages pertinentes
#     learning_rate = trial.suggest_float("learning_rate", 0.01, 0.1, log=True)  # Plage restreinte pour éviter un learning_rate trop élevé (>0.3)
#     max_depth = trial.suggest_int("max_depth", 3, 5)  # On explore une plage restreinte pour éviter des modèles trop complexes
#     subsample = trial.suggest_float("subsample", 0.7, 0.9)  # Plage affinée autour de 0.8

#     # Création du modèle avec early stopping activé
#     model = GradientBoostingRegressor(
#         n_estimators=n_estimators,
#         learning_rate=learning_rate,
#         max_depth=max_depth,
#         subsample=subsample,
#         random_state=42,
#         n_iter_no_change=10,         # Arrêt anticipé si aucune amélioration pendant 10 itérations
#         validation_fraction=0.1      # Utilisation de 10% des données d'entraînement pour l'early stopping
#     )

#     # Validation croisée temporelle (ici 5-fold) pour évaluer la performance de cette configuration
#     # Si le dataset est très volumineux, il peut être nécessaire de passer à 3-fold pour réduire le coût
#     tscv = TimeSeriesSplit(n_splits=5)
#     rmse_scores = []
#     for train_index, valid_index in tscv.split(X_train_scaled):
#         X_tr, X_val = X_train_scaled[train_index], X_train_scaled[valid_index]
#         y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]
        
#         model.fit(X_tr, y_tr)
#         y_pred = model.predict(X_val)
#         rmse = np.sqrt(mean_squared_error(y_val, y_pred))
#         rmse_scores.append(rmse)
    
#     # Retourne la moyenne des RMSE obtenues sur les différentes splits
#     return np.mean(rmse_scores)

# # Création de l'étude Optuna en mode minimisation de l'erreur RMSE
# study = optuna.create_study(direction="minimize")
# study.optimize(objective, n_trials=10)

# print("Meilleurs hyperparamètres trouvés :", study.best_trial.params)


# ----------------------------------------------------------------
# Étape 5 : Validation avec TimeSeriesSplit
# ----------------------------------------------------------------
tscv = TimeSeriesSplit(n_splits=10)
cv_rmse = []  # Stocker les erreurs pour chaque split

for train_index, val_index in tscv.split(X_train_scaled):
    X_tr, X_val = X_train_scaled[train_index], X_train_scaled[val_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[val_index]

    model = GradientBoostingRegressor(
        n_estimators=178,
        learning_rate=0.045,
        max_depth=3,
        subsample=0.85,
        random_state=42,
        n_iter_no_change=10,
        validation_fraction=0.1
    )

    model.fit(X_tr, y_tr)
    
    # Validation
    y_pred_val = model.predict(X_val)
    rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
    cv_rmse.append(rmse_val)

# Afficher la moyenne des RMSE sur les folds
print(f"Validation RMSE moyenne sur TimeSeriesSplit : {np.mean(cv_rmse):.2f}")

# ----------------------------------------------------------------
# Étape 6 : Entraînement du modèle final avec toutes les données d'entraînement
# ----------------------------------------------------------------
best_model = GradientBoostingRegressor(
    n_estimators=178,
    learning_rate=0.045,
    max_depth=3,
    subsample=0.85,
    random_state=42,
    n_iter_no_change=10,
    validation_fraction=0.1
)

best_model.fit(X_train_scaled, y_train)

# ----------------------------------------------------------------
# Étape 7 : Évaluation finale sur test set
# ----------------------------------------------------------------
y_pred_train = best_model.predict(X_train_scaled)
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
print(f"RMSE sur données d'entraînement: {rmse_train}")

y_pred_test = best_model.predict(X_test_scaled)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print(f"RMSE sur données de test: {rmse_test}")

# 1) MAE, MAPE, R²
mae_test = mean_absolute_error(y_test, y_pred_test)

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_test = mean_absolute_percentage_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)

print(f"MAE sur données de test: {mae_test}")
print(f"MAPE sur données de test: {mape_test:.2f}%")
print(f"R² sur données de test: {r2_test}")

# ----------------------------------------------------------------
# Étape 8 : Visualisation des erreurs et prédictions
# ----------------------------------------------------------------
plt.figure(figsize=(12, 6))
plt.plot(y_test.reset_index(drop=True), label='Valeurs Réelles')
plt.plot(y_pred_test, label='Prédictions')
plt.legend()
plt.title("Comparaison entre valeurs réelles et prédictions")
plt.xlabel("Index")
plt.ylabel("Prix de clôture")
plt.show()

# Importance des features
importances = best_model.feature_importances_
feature_importance_df = pd.DataFrame({'feature': features, 'importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)
print(feature_importance_df)

plt.figure(figsize=(12, 6))
plt.bar(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xticks(rotation=90)
plt.title("Importance des caractéristiques")
plt.xlabel("Caractéristiques")
plt.ylabel("Importance")
plt.show()

# ----------------------------------------------------------------
# Étape 9 : Enregistrement du modèle final
# ----------------------------------------------------------------
joblib.dump(best_model, 'gradient_boosting_model.pkl')
print("Modèle enregistré sous 'gradient_boosting_model.pkl'")
# Out:
# Nombre de valeurs NaN dans le DataFrame: 0

# %%
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
